# %% [markdown]
# # Test de création d'isochrones avec de nouvelles formes
#
# On se base sur l'API de Navitia pour obtenir les points qui permettent de composer les isochrones

# %%
# Add module to path
import os
import sys

add_path = os.getcwd().replace('experiments', '')
sys.path.append(add_path)

# %%
from dotenv import load_dotenv
import docopt
import json
from pathlib import Path
from csv_to_json import csv_to_json
from isos_and_intersections import GetIso

param_csv = os.path.join(add_path, "params/test_journeys.csv")
param_json = os.path.join(add_path, "params/test_journeys.json")
places_cache = os.path.join(add_path, "params/places_cache.json")

#Parameters
env_path = Path(add_path) / '.env'
load_dotenv(dotenv_path=env_path)
TOKEN = os.getenv("NAVITIA_TOKEN")

columns_with_array_of_str = [
    "colors_iso",
    "addresses",
    "excluded_modes",
    "durations"
    ]

#JSON INPUT
json_file = csv_to_json(param_csv, param_json, ";", columns_with_array_of_str)
# params_auto = json.load(open(json_file, encoding='utf-8'))

# test = json.loads(param_json)

gdf_global = GetIso(param_json, places_cache, api="navitia", token=TOKEN).get_all_isos()
# Out:
# PLACE 2.3467922;48.8621487
# DATETIME 2018-11-15T08:00
# URL https://api.navitia.io/v1/coverage/fr-idf/journeys?from=2.3467922;48.8621487&datetime=2018-11-15T08:00&boundary_duration[]=1200
# {'tickets': [], 'links': [{'href': 'https://api.navitia.io/v1/coverage/fr-idf/stop_points/{stop_point.id}', 'type': 'stop_point', 'rel': 'stop_points', 'templated': True}, {'href': 'https://api.navitia.io/v1/coverage/fr-idf/addresses/{address.id}', 'type': 'address', 'rel': 'addresses', 'templated': True}], 'journeys': [{'status': '', 'fare': {'found': False, 'links': []}, 'from': {'embedded_type': 'address', 'id': '2.3467922;48.8621487', 'quality': 0, 'name': '10 Passage de la Canopée (Paris)', 'address': {'house_number': 10, 'label': '10 Passage de la Canopée (Paris)', 'name': 'Passage de la Canopée', 'coord': {'lat': '48.8621487', 'lon': '2.3467922'}, 'id': '2.3467922;48.8621487'}}, 'links': [{'href': 'https://api.navitia.io/v1/coverage/fr-idf/journeys?to=stop_point%3AOIF%3ASP%3A59261&from=2.3467922%3B48.8621487&boundary_duration%5B%5D=1200&datetime=2018-11-15T08%3A00', 'type': 'journeys', 'rel': 'journeys', 'templated': False}], 'tags': [], 'nb_transfers': 0, 'arrival_date_time': '20181115T080400', 'co2_emission': {'value': 0.0, 'unit': ''}, 'to': {'embedded_type': 'stop_point', 'stop_point': {'codes': [{'type': 'SIRI_STIF', 'value': 'STIF:StopPoint:Q:22147:'}, {'type': 'ZDEr_ID_REF_A', 'value': '22147'}, {'type': 'external_code', 'value': 'OIF59261'}, {'type': 'source', 'value': 'StopPoint:59261'}], 'name': 'Etienne Marcel', 'links': [], 'coord': {'lat': '48.863713', 'lon': '2.349002'}, 'label': 'Etienne Marcel (Paris)', 'equipments': [], 'fare_zone': {'name': '1'}, 'id': 'stop_point:OIF:SP:59261'}, 'quality': 0, 'name': 'Etienne Marcel (Paris)', 'id': 'stop_point:OIF:SP:59261'}, 'requested_date_time': '20181115T080000', 'departure_date_time': '20181115T080000', 'duration': 240, 'type': ''}, {'status': '', 'fare': {'found': False, 'links': []}, 'from': {'embedded_type': 'address', 'id': '2.3467922;48.8621487', 'quality': 0, 'name': '10 Passage de la Canopée (Paris)', 'address': {'house_number': 10, 'label': '10 Passage de la Canopée (Paris)', 'name': 'Passage de la Canopée', 'coord': {'lat': '48.8621487', 'lon': '2.3467922'}, 'id': '2.3467922;48.8621487'}}, 'links': [{'href': 'https://api.navitia.io/v1/coverage/fr-idf/journeys?to=stop_point%3AOIF%3ASP%3A59627&from=2.3467922%3B48.8621487&boundary_duration%5B%5D=1200&datetime=2018-11-15T08%3A00', 'type': 'journeys', 'rel': 'journeys', 'templated': False}], 'tags': [], 'nb_transfers': 0, 'arrival_date_time': '20181115T080400', 'co2_emission': {'value': 0.0, 'unit': ''}, 'to': {'embedded_type': 'stop_point', 'stop_point': {'codes': [{'type': 'SIRI_STIF', 'value': 'STIF:StopPoint:Q:22092:'}, {'type': 'ZDEr_ID_REF_A', 'value': '22092'}, {'type': 'external_code', 'value': 'OIF59627'}, {'type': 'source', 'value': 'StopPoint:59627'}], 'name': 'Châtelet', 'links': [], 'coord': {'lat': '48.858303', 'lon': '2.347884'}, 'label': 'Châtelet (Paris)', 'equipments': [], 'fare_zone': {'name': '1'}, 'id': 'stop_point:OIF:SP:59627'}, 'quality': 0, 'name': 'Châtelet (Paris)', 'id': 'stop_point:OIF:SP:59627'}, 'requested_date_time': '20181115T080000', 'departure_date_time': '20181115T080000', 'duration': 240, 'type': ''}, {'status': '', 'fare': {'found': False, 'links': []}, 'from': {'embedded_type': 'address', 'id': '2.3467922;48.8621487', 'quality': 0, 'name': '10 Passage de la Canopée (Paris)', 'address': {'house_number': 10, 'label': '10 Passage de la Canopée (Paris)', 'name': 'Passage de la Canopée', 'coord': {'lat': '48.8621487', 'lon': '2.3467922'}, 'id': '2.3467922;48.8621487'}}, 'links': [{'href': 'https://api.navitia.io/v1/coverage/fr-idf/journeys?to=stop_point%3AOIF%3ASP%3A59625&from=2.3467922%3B48.8621487&boundary_duration%5B%5D=1200&datetime=2018-11-15T08%3A00', 'type': 'journeys', 'rel': 'journeys', 'templated': False}], 'tags': [], 'nb_transfers': 0, 'arrival_date_time': '20181115T080500', 'co2_emission': {'value': 0.0, 'unit': ''}, 'to': {'embedded_type': 'stop_point', 'stop_point': {'codes': [{'type': 'SIRI_STIF', 'value': 'STIF:StopPoint:Q:22142:'}, {'type': 'ZDEr_ID_REF_A',  ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-268b5e677933> in <module>()
#      28 # test = json.loads(param_json)
#      29
# ---> 30 gdf_global = GetIso(param_json, places_cache, api="navitia", token=TOKEN).get_all_isos()
#
# ~\Documents\code\iso\app_iso\code\isos_and_intersections.py in get_all_isos(self)
#     229                 from_place = self.places_cache[address]
#     230                 from_place = str(from_place[0]) +";"+str(from_place[1])
# --> 231                 gdf_poly = self.get_iso(param, from_place)
#     232                 l_param_gdf.append(gdf_poly)
#     233
#
# ~\Documents\code\iso\app_iso\code\isos_and_intersections.py in get_iso(self, param, from_place)
#     176             for iso,duration in zip(geojson_[param["option"]], list_time):
#     177                 multi = Feature(
# --> 178                         geometry=iso["geojson"],
#     179                         properties={
#     180                             "duration":duration,
#
# KeyError: 'geojson'

# %%
gdf_global

# %%
d = "2018-10-18"
from datetime import datetime

datetime_object = datetime.strptime(d, '%Y-%m-%d').isoformat()

# %%
TOKEN
# Out:
# 'bc126037-8569-4ecb-8369-719db7d0c998'
